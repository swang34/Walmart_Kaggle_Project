# %% [markdown]
# # Walmart Kaggle Project
#
# ### Authors:  Shijie Wang and Matthew Odom

# %%
# %ls
# Out:
# Walmart_Script.ipynb   test.csv               train.csv
# sample_submission.csv  test.csv.zip

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import random

# load the datasets
train = pd.read_csv("train.csv")
train = pd.get_dummies(train)
train = train.dropna()

test = pd.read_csv("test.csv")
test = pd.get_dummies(test)
test = test.dropna()

# subset for algorithm build
data = train[train["TripType"] <= 10]
data = data.sample(50000)

# clean dataset for modeling data.ix[random.sample(data.index, 50000)]
# create a loop for each TripType
# stack the output of the test

TripTypes = data.TripType.unique()
submission = pd.DataFrame()

for i in TripTypes:
    print "Working on TripType " + str(i)
    
    # reset dataset for next iteration
    sample = data
    sample = sample.dropna()
    
    # convert independent variable into binary
    sample.TripType = np.where(sample.TripType != i, 0, 1) 
    
    # set up model
    X = sample.ix[:,sample.columns != 'TripType']
    y = sample.ix[:,sample.columns == 'TripType']
    model = sm.OLS(y,X)
    results = model.fit()
    
    # predict test dataset values
    yhat = results.predict(X) # this should be results.predict(test)
    
    # append columns to submission
    submission = submission.join(pd.DataFrame(yhat), how = "outer")
# Out:
# "for i in TripTypes:\n    # reset dataset for next iteration\n    sample = data\n    sample = sample.dropna()\n    \n    # convert independent variable into binary\n    sample.TripType = np.where(sample.TripType != i, 0, 1) \n    \n    # set up model\n    X = sample.ix[:,sample.columns != 'TripType']\n    y = sample.ix[:,sample.columns == 'TripType']\n    model = sm.OLS(y,X)\n    results = model.fit()\n    \n    # predict test dataset values\n    yhat = results.predict(test)\n    \n    # append columns to submission"

# %%
submission = pd.DataFrame()
i=5
sample = data
sample = sample.dropna()

# convert independent variable into binary
sample.TripType = np.where(sample.TripType != i, 0, 1) 

# set up model
X = sample.ix[:,sample.columns != 'TripType']
y = sample.ix[:,sample.columns == 'TripType']
model = sm.OLS(y,X)
results = model.fit()

# predict test dataset values
yhat = results.predict(X)

# append columns to submission
submission = submission.join(pd.DataFrame(yhat), how = "outer")

#pd.concat([submission, pd.DataFrame(yhat)], axis=1)
submission
# Out:
#               0
# 0      0.762925
# 1      0.134669
# 2     -0.031365
# 3      0.071226
# 4      0.025883
# 5      0.063250
# 6      0.057436
# 7      0.058333
# 8      0.059009
# 9      0.067904
# 10     0.021671
# 11     0.023399
# 12     0.072929
# 13     0.212818
# 14     0.031840
# 15     0.024730
# 16     0.057041
# 17     0.052882
# 18     0.033073
# 19     0.007389
# 20     0.072292
# 21     0.025504
# 22     0.024003
# 23     0.079052
# 24     0.132649
# 25     0.063008
# 26     0.126252
# 27     0.077528
# 28     0.027287
# 29     0.102794
# ...         ...
# 49970  0.038039
# 49971  0.214088
# 49972  0.022813
# 49973  0.089915
# 49974  0.067024
# 49975  0.106251
# 49976  0.075574
# 49977  0.072864
# 49978  0.120903
# 49979  0.022239
# 49980  0.074465
# 49981  0.072677
# 49982  0.070398
# 49983  0.051025
# 49984  0.041227
# 49985  0.066093
# 49986  0.021600
# 49987  0.058086
# 49988  0.762117
# 49989  0.094208
# 49990  0.073350
# 49991  0.143485
# 49992  0.066454
# 49993  0.008107
# 49994  0.028441
# 49995  0.025458
# 49996  0.106316
# 49997  0.214257
# 49998  0.088642
# 49999  0.762536
#
# [50000 rows x 1 columns]

# %%
submission
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print results.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               TripType   R-squared:                       0.373
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     378.1
# Date:                Sat, 21 Nov 2015   Prob (F-statistic):               0.00
# Time:                        22:47:28   Log-Likelihood:                -5161.5
# No. Observations:               48456   AIC:                         1.048e+04
# Df Residuals:                   48379   BIC:                         1.115e+04
# Df Model:                          76
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------------------
# VisitNumber                                        1.585e-08   2.24e-08      0.707      0.479     -2.81e-08  5.98e-08
# Upc                                               -3.777e-14    1.8e-14     -2.094      0.036     -7.31e-14 -2.42e-15
# ScanCount                                             0.0149      0.002      6.875      0.000         0.011     0.019
# FinelineNumber                                     9.223e-08    5.5e-07      0.168      0.867     -9.85e-07  1.17e-06
# Weekday_Friday                                        0.0982      0.007     13.872      0.000         0.084     0.112
# Weekday_Monday                                        0.0998      0.007     13.756      0.000         0.086     0.114
# Weekday_Saturday                                      0.1059      0.007     14.946      0.000         0.092     0.120
# Weekday_Sunday                                        0.0919      0.007     12.818      0.000         0.078     0.106
# Weekday_Thursday                                      0.1048      0.007     14.160      0.000         0.090     0.119
# Weekday_Tuesday                                       0.1060      0.007     14.531      0.000         0.092     0.120
# Weekday_Wednesday                                     0.1037      0.007     14.169      0.000         0.089     0.118
# DepartmentDescription_1-HR PHOTO                     -0.0995      0.037     -2.718      0.007        -0.171    -0.028
# DepartmentDescription_ACCESSORIES                    -0.0377      0.025     -1.518      0.129        -0.086     0.011
# DepartmentDescription_AUTOMOTIVE                     -0.0737      0.012     -6.016      0.000        -0.098    -0.050
# DepartmentDescription_BAKERY                         -0.0729      0.010     -6.969      0.000        -0.093    -0.052
# DepartmentDescription_BATH AND SHOWER                -0.0425      0.021     -2.000      0.045        -0.084    -0.001
# DepartmentDescription_BEAUTY                          0.0281      0.010      2.692      0.007         0.008     0.049
# DepartmentDescription_BEDDING                        -0.0786      0.028     -2.776      0.006        -0.134    -0.023
# DepartmentDescription_BOOKS AND MAGAZINES            -0.0116      0.030     -0.390      0.696        -0.070     0.047
# DepartmentDescription_BOYS WEAR                      -0.0677      0.021     -3.218      0.001        -0.109    -0.026
# DepartmentDescription_BRAS & SHAPEWEAR               -0.0470      0.027     -1.737      0.082        -0.100     0.006
# DepartmentDescription_CAMERAS AND SUPPLIES           -0.0926      0.040     -2.289      0.022        -0.172    -0.013
# DepartmentDescription_CANDY, TOBACCO, COOKIES        -0.0387      0.010     -3.764      0.000        -0.059    -0.019
# DepartmentDescription_CELEBRATION                    -0.0326      0.013     -2.591      0.010        -0.057    -0.008
# DepartmentDescription_COMM BREAD                     -0.0764      0.010     -7.837      0.000        -0.095    -0.057
# DepartmentDescription_CONCEPT STORES                 -0.1219      0.188     -0.649      0.517        -0.490     0.247
# DepartmentDescription_COOK AND DINE                  -0.0299      0.016     -1.924      0.054        -0.060     0.001
# DepartmentDescription_DAIRY                          -0.0482      0.008     -5.928      0.000        -0.064    -0.032
# DepartmentDescription_DSD GROCERY                    -0.0463      0.007     -6.637      0.000        -0.060    -0.033
# DepartmentDescription_ELECTRONICS                    -0.0891      0.016     -5.737      0.000        -0.120    -0.059
# DepartmentDescription_FABRICS AND CRAFTS              0.0221      0.016      1.345      0.179        -0.010     0.054
# DepartmentDescription_FINANCIAL SERVICES             -0.1080      0.007    -14.422      0.000        -0.123    -0.093
# DepartmentDescription_FROZEN FOODS                   -0.0858      0.009     -9.997      0.000        -0.103    -0.069
# DepartmentDescription_FURNITURE                      -0.1104      0.071     -1.549      0.121        -0.250     0.029
# DepartmentDescription_GIRLS WEAR, 4-6X  AND 7-14     -0.0701      0.025     -2.855      0.004        -0.118    -0.022
# DepartmentDescription_GROCERY DRY GOODS              -0.0489      0.007     -6.638      0.000        -0.063    -0.034
# DepartmentDescription_HARDWARE                       -0.0435      0.014     -3.167      0.002        -0.070    -0.017
# DepartmentDescription_HEALTH AND BEAUTY AIDS       2.685e-12   1.67e-11      0.161      0.872     -3.01e-11  3.55e-11
# DepartmentDescription_HOME DECOR                     -0.0034      0.019     -0.178      0.859        -0.041     0.034
# DepartmentDescription_HOME MANAGEMENT                -0.0113      0.015     -0.760      0.448        -0.040     0.018
# DepartmentDescription_HORTICULTURE AND ACCESS        -0.0549      0.023     -2.371      0.018        -0.100    -0.010
# DepartmentDescription_HOUSEHOLD CHEMICALS/SUPP       -0.0344      0.011     -3.227      0.001        -0.055    -0.013
# DepartmentDescription_HOUSEHOLD PAPER GOODS          -0.0204      0.011     -1.784      0.074        -0.043     0.002
# DepartmentDescription_IMPULSE MERCHANDISE            -0.0317      0.007     -4.323      0.000        -0.046    -0.017
# DepartmentDescription_INFANT APPAREL                 -0.0629      0.025     -2.495      0.013        -0.112    -0.013
# DepartmentDescription_INFANT CONSUMABLE HARDLINES    -0.0666      0.015     -4.545      0.000        -0.095    -0.038
# DepartmentDescription_JEWELRY AND SUNGLASSES         -0.0571      0.016     -3.505      0.000        -0.089    -0.025
# DepartmentDescription_LADIES SOCKS                    0.1050      0.040      2.625      0.009         0.027     0.183
# DepartmentDescription_LADIESWEAR                     -0.0617      0.015     -4.189      0.000        -0.091    -0.033
# DepartmentDescription_LARGE HOUSEHOLD GOODS          -0.1149      0.045     -2.572      0.010        -0.202    -0.027
# DepartmentDescription_LAWN AND GARDEN                -0.0151      0.016     -0.953      0.341        -0.046     0.016
# DepartmentDescription_LIQUOR,WINE,BEER               -0.0853      0.012     -7.220      0.000        -0.108    -0.062
# DepartmentDescription_MEAT - FRESH & FROZEN          -0.1071      0.010    -10.285      0.000        -0.127    -0.087
# DepartmentDescription_MEDIA AND GAMING               -0.0475      0.023     -2.083      0.037        -0.092    -0.003
# DepartmentDescription_MENS WEAR                      -0.0586      0.011     -5.539      0.000        -0.079    -0.038
# DepartmentDescription_MENSWEAR                       -0.1151      0.052     -2.195      0.028        -0.218    -0.012
# DepartmentDescription_OFFICE SUPPLIES                -0.0245      0.013     -1.912      0.056        -0.050     0.001
# DepartmentDescription_OPTICAL - FRAMES                0.8589      0.018     47.723      0.000         0.824     0.894
# DepartmentDescription_OPTICAL - LENSES                0.8805      0.039     22.477      0.000         0.804     0.957
# DepartmentDescription_OTHER DEPARTMENTS              -0.1130      0.154     -0.736      0.462        -0.414     0.188
# DepartmentDescription_PAINT AND ACCESSORIES          -0.0770      0.023     -3.338      0.001        -0.122    -0.032
# DepartmentDescription_PERSONAL CARE                   0.1022      0.008     13.129      0.000         0.087     0.117
# DepartmentDescription_PETS AND SUPPLIES              -0.0077      0.014     -0.564      0.573        -0.035     0.019
# DepartmentDescription_PHARMACY OTC                    0.6404      0.007     90.877      0.000         0.627     0.654
# DepartmentDescription_PHARMACY RX                     0.8792      0.032     27.808      0.000         0.817     0.941
# DepartmentDescription_PLAYERS AND ELECTRONICS        -0.1154      0.034     -3.366      0.001        -0.183    -0.048
# DepartmentDescription_PLUS AND MATERNITY             -0.0717      0.052     -1.367      0.172        -0.175     0.031
# DepartmentDescription_PRE PACKED DELI                -0.0983      0.013     -7.527      0.000        -0.124    -0.073
# DepartmentDescription_PRODUCE                        -0.0429      0.007     -5.835      0.000        -0.057    -0.028
# DepartmentDescription_SEAFOOD                        -0.1099      0.020     -5.454      0.000        -0.149    -0.070
# DepartmentDescription_SEASONAL                        0.8801      0.266      3.311      0.001         0.359     1.401
# DepartmentDescription_SERVICE DELI                   -0.0960      0.008    -11.847      0.000        -0.112    -0.080
# DepartmentDescription_SHEER HOSIERY                   0.0118      0.043      0.274      0.784        -0.072     0.096
# DepartmentDescription_SHOES                          -0.0652      0.014     -4.608      0.000        -0.093    -0.037
# DepartmentDescription_SLEEPWEAR/FOUNDATIONS          -0.0274      0.025     -1.091      0.275        -0.077     0.022
# DepartmentDescription_SPORTING GOODS                 -0.0705      0.014     -5.045      0.000        -0.098    -0.043
# DepartmentDescription_SWIMWEAR/OUTERWEAR             -0.1139      0.042     -2.717      0.007        -0.196    -0.032
# DepartmentDescription_TOYS                           -0.0810      0.015     -5.446      0.000        -0.110    -0.052
# DepartmentDescription_WIRELESS                       -0.0622      0.020     -3.081      0.002        -0.102    -0.023
# ==============================================================================
# Omnibus:                    20399.909   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           114819.986
# Skew:                           1.967   Prob(JB):                         0.00
# Kurtosis:                       9.434   Cond. No.                     9.54e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.54e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
